# %% [markdown]
# # Session 13 – Advanced Lab Sheet

# %% [markdown]
# ## PART A — Load and Explore the Dataset

# %% [markdown]
# ### Q1. Import required libraries.

# %%
import pandas as pd
import numpy as np  
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Q2. Load the dataset.

# %%
file_path = 'C:\Users\USER\OneDrive\Documents\Year_2_Semester_1\Real_World_Analytics\pandas\practice_11\student_performance.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   Cell In[5], line 1
#     file_path = 'C:\Users\USER\OneDrive\Documents\Year_2_Semester_1\Real_World_Analytics\pandas\practice_11\student_performance.csv'
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
